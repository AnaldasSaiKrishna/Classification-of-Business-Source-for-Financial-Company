# %%
import os

# %%
os.chdir('F:\Analytics Vidhya Al & ML\INTRODUCTION TO DATA SCIENCE\Classification')

# %%
import pandas as pd

# %%
Train=pd.read_csv('Train.csv')

# %%
Test=pd.read_csv('Test.csv')

# %%
Train['source']='Train'
Test['source']='Test'

# %%
data = pd.concat([Train, Test],ignore_index=True)
# Out:
# C:\Users\Saikrizna\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
Train.shape,Test.shape,data.shape
# Out:
# ((9527, 24), (5045, 23), (14572, 24))

# %%
data.isnull().sum()
# Out:
# Applicant_BirthDate              96
# Applicant_City_PIN              131
# Applicant_Gender                 89
# Applicant_Marital_Status        103
# Applicant_Occupation           2225
# Applicant_Qualification         130
# Application_Receipt_Date       2576
# Business_Sourced               5045
# ID                                0
# Manager_Business               1507
# Manager_Business2              1507
# Manager_Current_Designation    1507
# Manager_DOJ                    1507
# Manager_DoB                    1507
# Manager_Gender                 1507
# Manager_Grade                  1507
# Manager_Joining_Designation    1507
# Manager_Num_Application        1507
# Manager_Num_Coded              1507
# Manager_Num_Products           1507
# Manager_Num_Products2          1507
# Manager_Status                 1507
# Office_PIN                        0
# source                            0
# dtype: int64

# %%
New_data =data.drop(['Applicant_City_PIN',"Applicant_BirthDate","Application_Receipt_Date","ID",'Office_PIN',"Manager_DOJ",'Manager_DoB'],axis=1)

# %%
New_data.tail(20)
# Out:
#       Applicant_Gender Applicant_Marital_Status Applicant_Occupation  \
# 14552                M                        S                  NaN
# 14553                M                        M                  NaN
# 14554                M                        M                  NaN
# 14555                M                        S                  NaN
# 14556                M                        M             Salaried
# 14557                M                        M             Business
# 14558                M                        M               Others
# 14559                F                        M             Salaried
# 14560                M                        M        Self Employed
# 14561                M                        M        Self Employed
# 14562                M                        M        Self Employed
# 14563                M                        M             Business
# 14564                M                        M             Business
# ...

# %%
New_data.isnull().sum()
# Out:
# Applicant_Gender                 89
# Applicant_Marital_Status        103
# Applicant_Occupation           2225
# Applicant_Qualification         130
# Business_Sourced               5045
# Manager_Business               1507
# Manager_Business2              1507
# Manager_Current_Designation    1507
# Manager_Gender                 1507
# Manager_Grade                  1507
# Manager_Joining_Designation    1507
# Manager_Num_Application        1507
# Manager_Num_Coded              1507
# Manager_Num_Products           1507
# Manager_Num_Products2          1507
# Manager_Status                 1507
# source                            0
# dtype: int64

# %%
pd.crosstab(New_data['Applicant_Gender'],New_data['Applicant_Occupation'],margins=True)
# Out:
# Applicant_Occupation  Business  Others  Salaried  Self Employed  Student  \
# Applicant_Gender
# F                          425     791      1588             63       47
# M                         2524    1679      4756            396       73
# All                       2949    2470      6344            459      120
#
# Applicant_Occupation    All
# Applicant_Gender
# F                      2914
# M                      9428
# All                   12342

# %%
pd.crosstab(New_data['Applicant_Qualification'],New_data['Applicant_Gender'],margins=True)
# Out:
# Applicant_Gender                                       F      M    All
# Applicant_Qualification
# Associate / Fellow of Institute of Chartered Ac...     1      4      5
# Associate/Fellow of Acturial Society of India          0      1      1
# Associate/Fellow of Institute of Company Secret...     0      1      1
# Associate/Fellow of Institute of Institute of C...     0      1      1
# Associate/Fellow of Insurance Institute of India       0      1      1
# Certified Associateship of Indian Institute of ...     1      0      1
# Class X                                               28    216    244
# Class XII                                           1585   5577   7162
# Graduate                                            1678   4889   6567
# Masters of Business Administration                    26    119    145
# Others                                                76    227    303
# Professional Qualification in Marketing                2      4      6
# ...

# %%
pd.crosstab(New_data['Business_Sourced'],New_data['Applicant_Gender'],margins=True)
# Out:
# Applicant_Gender     F     M   All
# Business_Sourced
# 0.0               1402  4791  6193
# 1.0                879  2388  3267
# All               2281  7179  9460

# %%
New_data.dtypes
# Out:
# Applicant_Gender                object
# Applicant_Marital_Status        object
# Applicant_Occupation            object
# Applicant_Qualification         object
# Business_Sourced               float64
# Manager_Business               float64
# Manager_Business2              float64
# Manager_Current_Designation     object
# Manager_Gender                  object
# Manager_Grade                  float64
# Manager_Joining_Designation     object
# Manager_Num_Application        float64
# Manager_Num_Coded              float64
# Manager_Num_Products           float64
# Manager_Num_Products2          float64
# Manager_Status                  object
# source                          object
# dtype: object

# %%
New_data.Applicant_Gender.value_counts()
# Out:
# M    11079
# F     3404
# Name: Applicant_Gender, dtype: int64

# %%
New_data.Applicant_Occupation.value_counts()
# Out:
# Salaried         6347
# Business         2949
# Others           2472
# Self Employed     459
# Student           120
# Name: Applicant_Occupation, dtype: int64

# %%
New_data['Applicant_Gender'].fillna('M',inplace=True)

# %%
New_data.Applicant_Marital_Status.value_counts()
# Out:
# M    10266
# S     4174
# W       18
# D       11
# Name: Applicant_Marital_Status, dtype: int64

# %%
New_data['Applicant_Marital_Status'].fillna('M',inplace=True)

# %%
New_data['Applicant_Occupation'].fillna('Salaried',inplace=True)

# %%
New_data.Applicant_Qualification.value_counts()
# Out:
# Class XII                                                                             7163
# Graduate                                                                              6571
# Others                                                                                 303
# Class X                                                                                244
# Masters of Business Administration                                                     145
# Professional Qualification in Marketing                                                  6
# Associate / Fellow of Institute of Chartered Accountans of India                         5
# Associate/Fellow of Institute of Institute of Costs and Works Accountants of India       1
# Associate/Fellow of Institute of Company Secretories of India                            1
# Associate/Fellow of Acturial Society of India                                            1
# ...

# %%
New_data['Applicant_Qualification'].fillna('Class XII',inplace=True)

# %%
New_data.Manager_Current_Designation.value_counts()
# Out:
# Level 2    4648
# Level 3    3563
# Level 1    3366
# Level 4    1365
# Level 5     123
# Name: Manager_Current_Designation, dtype: int64

# %%
New_data['Manager_Current_Designation'].fillna('Level 2',inplace=True)

# %%
New_data.Manager_Gender.value_counts()
# Out:
# M    11321
# F     1744
# Name: Manager_Gender, dtype: int64

# %%
New_data['Manager_Gender'].fillna('M',inplace=True)

# %%
New_data.Manager_Joining_Designation.value_counts()
# Out:
# Level 1    5849
# Level 2    4228
# Level 3    2483
# Level 4     408
# Other        58
# Level 6      21
# Level 5      16
# Level 7       2
# Name: Manager_Joining_Designation, dtype: int64

# %%
New_data['Manager_Joining_Designation'].fillna('Level 1',inplace=True)

# %%
New_data.Manager_Status.value_counts()
# Out:
# Confirmation    7206
# Probation       5859
# Name: Manager_Status, dtype: int64

# %%
New_data['Manager_Status'].fillna('Confirmation',inplace=True)

# %%
New_data.isnull().sum()
# Out:
# Applicant_Gender                  0
# Applicant_Marital_Status          0
# Applicant_Occupation              0
# Applicant_Qualification           0
# Business_Sourced               5045
# Manager_Business               1507
# Manager_Business2              1507
# Manager_Current_Designation       0
# Manager_Gender                    0
# Manager_Grade                  1507
# Manager_Joining_Designation       0
# Manager_Num_Application        1507
# Manager_Num_Coded              1507
# Manager_Num_Products           1507
# Manager_Num_Products2          1507
# Manager_Status                    0
# source                            0
# dtype: int64

# %%
New_data['Manager_Business'].fillna(New_data['Manager_Business'].median(),inplace=True)
New_data['Manager_Business2'].fillna(New_data['Manager_Business2'].median(),inplace=True)
New_data['Manager_Num_Products'].fillna(New_data['Manager_Num_Products'].mean(),inplace=True)
New_data['Manager_Num_Products2'].fillna(New_data['Manager_Num_Products2'].mean(),inplace=True)

# %%
New_data['Manager_Grade'].fillna(0,inplace=True)

# %%
New_data.isnull().sum()
# Out:
# Applicant_Gender                  0
# Applicant_Marital_Status          0
# Applicant_Occupation              0
# Applicant_Qualification           0
# Business_Sourced               5045
# Manager_Business                  0
# Manager_Business2                 0
# Manager_Current_Designation       0
# Manager_Gender                    0
# Manager_Grade                     0
# Manager_Joining_Designation       0
# Manager_Num_Application        1507
# Manager_Num_Coded              1507
# Manager_Num_Products              0
# Manager_Num_Products2             0
# Manager_Status                    0
# source                            0
# dtype: int64

# %%
New_data.corr()
# Out:
#                          Business_Sourced  Manager_Business  \
# Business_Sourced                 1.000000          0.030130
# Manager_Business                 0.030130          1.000000
# Manager_Business2                0.029652          0.984004
# Manager_Grade                    0.044414          0.273803
# Manager_Num_Application         -0.037593          0.050290
# Manager_Num_Coded                0.013565          0.166112
# Manager_Num_Products            -0.010642          0.739194
# Manager_Num_Products2           -0.011327          0.727120
#
#                          Manager_Business2  Manager_Grade  \
# Business_Sourced                  0.029652       0.044414
# Manager_Business                  0.984004       0.273803
# Manager_Business2                 1.000000       0.268201
# Manager_Grade                     0.268201       1.000000
# Manager_Num_Application           0.045384      -0.005458
# Manager_Num_Coded                 0.163220       0.017870
# ...

# %%
New_data.drop(['Manager_Num_Application','Manager_Num_Coded'],axis=1)
# Out:
#       Applicant_Gender Applicant_Marital_Status Applicant_Occupation  \
# 0                    M                        M               Others
# 1                    M                        S               Others
# 2                    M                        M             Business
# 3                    M                        S             Salaried
# 4                    M                        M               Others
# 5                    M                        S               Others
# 6                    M                        M             Business
# 7                    M                        M             Salaried
# 8                    M                        M             Business
# 9                    M                        M               Others
# 10                   M                        M             Salaried
# 11                   F                        S             Business
# 12                   M                        S             Business
# ...

# %%
New_data.head(10)
# Out:
#   Applicant_Gender Applicant_Marital_Status Applicant_Occupation  \
# 0                M                        M               Others
# 1                M                        S               Others
# 2                M                        M             Business
# 3                M                        S             Salaried
# 4                M                        M               Others
# 5                M                        S               Others
# 6                M                        M             Business
# 7                M                        M             Salaried
# 8                M                        M             Business
# 9                M                        M               Others
#
#   Applicant_Qualification  Business_Sourced  Manager_Business  \
# 0                Graduate               0.0          335249.0
# 1               Class XII               1.0          335249.0
# ...

# %%
train = data.loc[New_data['source']=="Train"]
test = data.loc[New_data['source']=="test"]

# %%
test.drop(['Business_Sourced','source'],axis=1,inplace=True)
train.drop(['source'],axis=1,inplace=True)

# %%
train.to_csv("train_modified.csv",index=False)
test.to_csv("test_modified.csv",index=False)

# %%
trainmod=pd.read_csv('train_modified.csv')

# %%
trainmod.head()
# Out:
#   Applicant_BirthDate  Applicant_City_PIN Applicant_Gender  \
# 0          12/19/1971            844120.0                M
# 1           2/17/1983            844111.0                M
# 2           1/16/1966            844101.0                M
# 3            2/3/1988            814112.0                M
# 4            7/4/1985            815351.0                M
#
#   Applicant_Marital_Status Applicant_Occupation Applicant_Qualification  \
# 0                        M               Others                Graduate
# 1                        S               Others               Class XII
# 2                        M             Business               Class XII
# 3                        S             Salaried               Class XII
# 4                        M               Others               Class XII
#
#   Application_Receipt_Date  Business_Sourced          ID  Manager_Business  \
# 0                4/16/2007               0.0  FIN1000001          335249.0
# ...

# %%
#trainmod.drop(['Applicant_BirthDate', 'Applicant_City_PIN','Application_Receipt_Date','ID',])
